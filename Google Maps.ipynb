# %%
import requests
from urllib.parse import urlencode
import json
from gmplot import gmplot

# %%
api_key ='AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8'

# %% [markdown]
# # Шымкент

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования шымкент",
    "type": "Shymkent"
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D1%88%D1%8B%D0%BC%D0%BA%D0%B5%D0%BD%D1%82&type=Shymkent

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text

# %%
r.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'ул. Ахмет Байтурсынова 20 Б, Shymkent, Kazakhstan',
#    'geometry': {'location': {'lat': 42.3439488, 'lng': 69.6112757},
#     'viewport': {'northeast': {'lat': 42.34506392989272,
#       'lng': 69.61261232989273},
#      'southwest': {'lat': 42.34236427010728, 'lng': 69.60991267010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'Школа программирования ITSTART Шымкент',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJg3H-hBgcqTgRHcNls9Odups',
#    'plus_code': {'compound_code': '8JV6+HG Shymkent',
#     'global_code': '8JJF8JV6+HG'},
#    'rating': 5,
#    'reference': 'ChIJg3H-hBgcqTgRHcNls9Odups',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Qazybek Bi St, Shymkent 160000, Kazakhstan',
# ...

# %%
data = json.loads(r2)

# %%
data2 = data['results']

# %%
Shymkent=[]

for i in data2:
    print(i['name'])
    Shymkent.append(i['name'])
# Out:
# Школа программирования ITSTART Шымкент
# Школа программирования HITECH SCHOOL SHYMKENT
# Kursy Programmirovaniya V Shymkente
# Школа программирования JUNIORIT
# Mezhdunarodnaya Shkola Dizayna I Programmirovaniya

# %%
Shymkent
# Out:
# ['Школа программирования ITSTART Шымкент',
#  'Школа программирования HITECH SCHOOL SHYMKENT',
#  'Kursy Programmirovaniya V Shymkente',
#  'Школа программирования JUNIORIT',
#  'Mezhdunarodnaya Shkola Dizayna I Programmirovaniya']

# %%
ShymkentGeo=[]

for i in data2:
    ShymkentGeo.append(i['geometry']['location'])

# %%
ShymkentGeo
# Out:
# [{'lat': 42.3439488, 'lng': 69.6112757},
#  {'lat': 42.3240687, 'lng': 69.6067},
#  {'lat': 42.3208953, 'lng': 69.58055159999999},
#  {'lat': 42.329284, 'lng': 69.5970023},
#  {'lat': 42.3213791, 'lng': 69.5791572}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(42.3439488, 69.6112757, 13)

# Add a marker
gmap.marker(42.3439488, 69.6112757, 'cornflowerblue')
gmap.marker(42.3240687, 69.6067, 'cornflowerblue')
gmap.marker(42.3208953, 69.58055159999999, 'cornflowerblue')
gmap.marker(42.329284, 69.5970023, 'cornflowerblue')
gmap.marker(42.3213791, 69.5791572, 'cornflowerblue')

gmap.marker(42.3052730883907, 69.59688166090777, 'red')
gmap.marker(42.33984118738718, 69.60538241029927, 'red') 
gmap.marker(42.335526924779515, 69.64992853643648, 'red')

# Draw map into HTML file
gmap.draw("Shymkent.html")

# %% [markdown]
# # Алматы

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования Алматы",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%90%D0%BB%D0%BC%D0%B0%D1%82%D1%8B

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r.json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJ0WH8Izo_tSm4IV0Mv3yYWi1NR1ofitIXXWrwryv-tSTqWPOxFEk-xZ2HOVESnJ42EqMsDnCZ15VguWHHpBrgL4MmRQhfMgIT_3WpyqaXOecK6nX-n68_12-b1qHoMsYlE8XQoe60DmTUnz2nZJPZlJXh_eOLe6bnvSUkil5BNtGAlNWbNNCyljvDeZszm1giwy_vJ5HfF1xhHRLVyTce27UVtWTOYC7DBKOfDXvZAfjsl-yW09QbCx2oV5L6WyK7IZ9XwEPI2DAr-9_obs56kW1SHV_TShFLa9ljJ6EhnPghQHEvFXjKuDRaeDjaiTmY_oDu9ohOnPUqEuQpZhNKUUk2M_jN3I32LuRCV9nD3J9egKAWEScMJTLd28piitEmRMGfDsls2Z_dG3xmP0Dsb8F5crA_L3Z6tu8mcnUzWQ_oTmMmmWTySrIC6vYACCiZvlXJC',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Aimanov St 126, Almaty 050000, Kazakhstan',
#    'geometry': {'location': {'lat': 43.2376794, 'lng': 76.89740619999999},
#     'viewport': {'northeast': {'lat': 43.23902357989272,
#       'lng': 76.89867817989273},
#      'southwest': {'lat': 43.23632392010728, 'lng': 76.89597852010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
# ...

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Almaty=[]

for i in data2:
    Almaty.append(i['name'])

# %%
Almaty
# Out:
# ['BITLAB Academy | Школа Программирования',
#  'Decode | Курсы программирования',
#  'Школа программирования в Алматы - IT School',
#  'Школа программирования KnewIT',
#  'Школа программирования Codeway',
#  'Школа программирования для детей Love to Code',
#  'Shkola Programmirovaniya Dlya Detey Yuniorkod',
#  'Школа программирования',
#  'Школа программирования для детей Love to Code',
#  'Курс Программирования с нуля - CodeGuru',
#  'Курсы программирования Keynote',
#  'Школа программирования ELEMENT',
#  'TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирования | Обучение программированию',
#  'Школа программирования NewLine',
#  'KnewIT',
#  'Школа программирования ITCreed',
#  'Algoritmika Almaty',
#  'Akademiya Shag Almaty',
#  'Pervaya Shkola Programirovaniya',
#  'Method Coding School']

# %%
AlmatyGeo=[]

for i in data2:
    AlmatyGeo.append(i['geometry']['location'])

# %%
AlmatyGeo
# Out:
# [{'lat': 43.2376794, 'lng': 76.89740619999999},
#  {'lat': 43.2380699, 'lng': 76.9137973},
#  {'lat': 43.2351, 'lng': 76.9099014},
#  {'lat': 43.2631325, 'lng': 76.9276804},
#  {'lat': 43.3270746, 'lng': 76.9247955},
#  {'lat': 43.2159755, 'lng': 76.8701902},
#  {'lat': 43.2521271, 'lng': 76.89077929999999},
#  {'lat': 43.2579834, 'lng': 76.9110298},
#  {'lat': 43.2509446, 'lng': 76.9601978},
#  {'lat': 43.2375723, 'lng': 76.91292779999999},
#  {'lat': 43.2380699, 'lng': 76.9137973},
#  {'lat': 43.2377768, 'lng': 76.911591},
#  {'lat': 43.2508112, 'lng': 76.946806},
#  {'lat': 43.2372245, 'lng': 76.9331849},
#  {'lat': 43.263117, 'lng': 76.9276928},
#  {'lat': 43.239846, 'lng': 76.90185199999999},
#  {'lat': 43.2461482, 'lng': 76.9260887},
#  {'lat': 43.2391981, 'lng': 76.90500519999999},
#  {'lat': 43.2301205, 'lng': 76.89517130000002},
#  {'lat': 43.2374166, 'lng': 76.91521259999999}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(43.2376794, 76.89740619999999,13)

# Add a marker
gmap.marker(43.2376794, 76.89740619999999, 'cornflowerblue')
gmap.marker(43.2380699, 76.9137973, 'cornflowerblue')
gmap.marker(43.2351, 76.9099014, 'cornflowerblue')
gmap.marker(43.2631325, 76.9276804, 'cornflowerblue')
gmap.marker(43.3270746, 76.9247955, 'cornflowerblue')
gmap.marker(43.2159755, 76.8701902, 'cornflowerblue')
gmap.marker(43.2521271, 76.89077929999999, 'cornflowerblue')
gmap.marker(43.2579834, 76.9110298, 'cornflowerblue')
gmap.marker(43.2509446, 76.9601978, 'cornflowerblue')
gmap.marker(43.2375723, 76.91292779999999, 'cornflowerblue')
gmap.marker(43.2380699, 76.9137973, 'cornflowerblue')
gmap.marker(43.2377768, 76.911591, 'cornflowerblue')
gmap.marker(43.2508112, 76.946806, 'cornflowerblue')
gmap.marker(43.2372245, 76.9331849, 'cornflowerblue')
gmap.marker(43.263117, 76.9276928, 'cornflowerblue')
gmap.marker(43.239846, 76.90185199999999, 'cornflowerblue')
gmap.marker(43.2461482, 76.9260887, 'cornflowerblue')
gmap.marker(43.2391981, 76.90500519999999, 'cornflowerblue')
gmap.marker(43.2301205, 76.89517130000002, 'cornflowerblue')
gmap.marker(43.2374166, 76.91521259999999, 'cornflowerblue')

gmap.marker(43.23662525403574, 76.92974368444, 'red') 
gmap.marker(43.255602755313745, 76.94312650419225, 'red') 
#gmap.marker(43.242166390579925, 76.95289778972162, 'red') 
gmap.marker(43.234678043219674, 76.93112482676837, 'red') 
gmap.marker(43.25287050610048, 76.9263269825901, 'red') 
gmap.marker(43.23530270849879, 76.90977698443994, 'red') 

# Draw map into HTML file
gmap.draw("Almayt.html")

# %% [markdown]
# # Нур-Султан

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования в Нур-Султане",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%B2+%D0%9D%D1%83%D1%80-%D0%A1%D1%83%D0%BB%D1%82%D0%B0%D0%BD%D0%B5

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
NurSultan=[]

for i in data2:
    NurSultan.append(i['name'])

# %%
NurSultan
# Out:
# ['Shkola Programmirovaniya Dlya Detey "Softium"',
#  'ROBOSPACE - Школа робототехники и программирования',
#  'Компьютерная Академия ШАГ. Казахстан',
#  'Курсы программирования | Decode',
#  'Академия ШАГ Астана Левый берег',
#  'Mezhdunarodnaya Shkola Professiy',
#  'Kaysar777',
#  'ELC Astana - Английский в Астане (Левый Берег)',
#  'Курсы английского языка в Астане English House',
#  'Центр программирования Runtime',
#  'Aytilekt',
#  'Центр Профессиональной Подготовки «Академия Роста»',
#  'Гимназия №6',
#  'Art School KZ Курсы вокала, Уроки фортепиано, курсы гитары в Астане, курсы барабаны ударные',
#  'Центр Профессиональной Подготовки «Академия Роста»',
#  'Tsentr Nlp I Kouchinga V Astane',
#  'NIS',
#  'Kursy Astana',
#  "Shkola Krasoty Ekol'",
#  'Podgotovka K Shkole.']

# %%
##NurSultan.remove('Школа-лицей 66')

# %%
NurSultan.remove('NIS')
NurSultan.remove('ELC Astana - Английский в Астане (Левый Берег)')
NurSultan.remove('Курсы английского языка в Астане English House')
NurSultan.remove('Podgotovka K Shkole.')

# %%
NurSultan.remove("Shkola Krasoty Ekol'")
NurSultan.remove('Гимназия №6')

# %%
NurSultan
# Out:
# ['Shkola Programmirovaniya Dlya Detey "Softium"',
#  'ROBOSPACE - Школа робототехники и программирования',
#  'Компьютерная Академия ШАГ. Казахстан',
#  'Курсы программирования | Decode',
#  'Академия ШАГ Астана Левый берег',
#  'Mezhdunarodnaya Shkola Professiy',
#  'Kaysar777',
#  'Центр программирования Runtime',
#  'Aytilekt',
#  'Центр Профессиональной Подготовки «Академия Роста»',
#  'Art School KZ Курсы вокала, Уроки фортепиано, курсы гитары в Астане, курсы барабаны ударные',
#  'Центр Профессиональной Подготовки «Академия Роста»',
#  'Tsentr Nlp I Kouchinga V Astane',
#  'Kursy Astana']

# %%
NurSultanGeo=[]

for i in data2: #14, 7,8,16
    NurSultanGeo.append(i['geometry']['location'])

# %%
del NurSultanGeo[16]
del NurSultanGeo[15]
del NurSultanGeo[14]
del NurSultanGeo[12]
del NurSultanGeo[8]
del NurSultanGeo[7]

# %%
NurSultanGeo
# Out:
# [{'lat': 51.1539059, 'lng': 71.4989914},
#  {'lat': 51.14691639999999, 'lng': 71.4753933},
#  {'lat': 51.1852333, 'lng': 71.40690599999999},
#  {'lat': 51.2352858, 'lng': 71.4143205},
#  {'lat': 51.1231148, 'lng': 71.434456},
#  {'lat': 51.1599248, 'lng': 71.406046},
#  {'lat': 51.1466678, 'lng': 71.47745309999999},
#  {'lat': 51.16467, 'lng': 71.441425},
#  {'lat': 51.1609949, 'lng': 71.4355248},
#  {'lat': 51.1436591, 'lng': 71.4158732},
#  {'lat': 51.0978825, 'lng': 71.4226479},
#  {'lat': 51.1593571, 'lng': 71.4376502},
#  {'lat': 51.1599248, 'lng': 71.406046},
#  {'lat': 51.1546386, 'lng': 71.4512331}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(51.1539059, 71.4989914,13)

# Add a marker
gmap.marker(51.1539059, 71.4989914, 'cornflowerblue')
gmap.marker(51.14691639999999, 71.4753933, 'cornflowerblue')
gmap.marker(51.1852333, 71.40690599999999, 'cornflowerblue')
gmap.marker(51.2352858, 71.4143205, 'cornflowerblue')
gmap.marker(51.1231148, 71.434456, 'cornflowerblue')
gmap.marker(51.1599248, 71.406046, 'cornflowerblue')
gmap.marker(51.1466678, 71.47745309999999, 'cornflowerblue')
gmap.marker(51.16467, 71.441425, 'cornflowerblue')
gmap.marker(51.1609949, 71.4355248, 'cornflowerblue')
gmap.marker(51.1436591, 71.4158732, 'cornflowerblue')
gmap.marker(51.0978825, 71.4226479, 'cornflowerblue')
gmap.marker(51.1593571, 71.4376502, 'cornflowerblue')
gmap.marker(51.1599248, 71.406046, 'cornflowerblue')
gmap.marker(51.1546386, 71.4512331, 'cornflowerblue')


gmap.marker(51.16964442152685, 71.40765194367495, 'red') 
gmap.marker(51.18535638621766, 71.4330578267898, 'red') 

# Draw map into HTML file
gmap.draw("NurSultan.html")

# %% [markdown]
# # Актобе

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования Актобе",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%90%D0%BA%D1%82%D0%BE%D0%B1%D0%B5

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Aktobe=[]

for i in data2:
    Aktobe.append(i['name'])

# %%
Aktobe
# Out:
# ['Pk Programmist',
#  'Robotix - школа робототехники в Актобе',
#  'Языковой центр «АСЕРАС»',
#  '№ 9 орта мектеп - гимназия',
#  'Too "Uts Znaniye Aktobe"',
#  'Khudozhestvennyy Litsey Goroda Aktobe',
#  'Nazarbayev Intellectual School',
#  'Aktobe University named after Bayishev',
#  'Shkola Kursy Massazha Renessans']

# %%
Aktobe.remove('№ 9 орта мектеп - гимназия')
Aktobe.remove('Языковой центр «АСЕРАС»')
Aktobe.remove('Khudozhestvennyy Litsey Goroda Aktobe')
Aktobe.remove('Nazarbayev Intellectual School')
Aktobe.remove('Shkola Kursy Massazha Renessans')

# %%
Aktobe.remove('Aktobe University named after Bayishev')

# %%
Aktobe
# Out:
# ['Pk Programmist',
#  'Robotix - школа робототехники в Актобе',
#  'Too "Uts Znaniye Aktobe"']

# %%
AktobeGeo=[]

for i in data2:
    AktobeGeo.append(i['geometry']['location'])

# %%
del AktobeGeo[8]
del AktobeGeo[7]
del AktobeGeo[6]
del AktobeGeo[5]
del AktobeGeo[3]
del AktobeGeo[2]

# %%
AktobeGeo
# Out:
# [{'lat': 50.29429950000001, 'lng': 57.1654041},
#  {'lat': 50.2884052, 'lng': 57.1659747},
#  {'lat': 50.2963984, 'lng': 57.1561017}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(50.29429950000001, 57.1654041,13)

# Add a marker
gmap.marker(50.29429950000001, 57.1654041, 'cornflowerblue')
gmap.marker(50.2884052, 57.1659747, 'cornflowerblue')
gmap.marker(50.2963984, 57.1561017, 'cornflowerblue')



gmap.marker(50.28240070146561, 57.16130580229323, 'red') 
gmap.marker(50.28980435752049, 57.15298022573194, 'red') 

# Draw map into HTML file
gmap.draw("Aktobe.html")

# %% [markdown]
# # Караганда

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования Караганда",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%9A%D0%B0%D1%80%D0%B0%D0%B3%D0%B0%D0%BD%D0%B4%D0%B0

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Karaganda=[]

for i in data2:
    Karaganda.append(i['name'])

# %%
Karaganda
# Out:
# ['Akademiya Shag Karagandy',
#  'ikurs.kz образовательный центр',
#  'Учебный центр Personal - Курсы в Караганде',
#  'State School 43']

# %%
KaragandaGeo=[]

for i in data2:
    KaragandaGeo.append(i['geometry']['location'])

# %%
KaragandaGeo
# Out:
# [{'lat': 49.797829, 'lng': 73.09049999999999},
#  {'lat': 49.8164831, 'lng': 73.1018766},
#  {'lat': 49.7972366, 'lng': 73.0954616},
#  {'lat': 49.7848605, 'lng': 73.116314}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(49.797829, 73.09049999999999,13)

# Add a marker
gmap.marker(49.797829, 73.09049999999999, 'cornflowerblue')
gmap.marker(49.8164831, 73.1018766, 'cornflowerblue')
gmap.marker(49.7972366, 73.0954616, 'cornflowerblue')
gmap.marker(49.7848605, 73.116314, 'cornflowerblue')



gmap.marker(49.81888402480654, 73.10444275787144, 'red') 


# Draw map into HTML file
gmap.draw("Karaganda.html")

# %% [markdown]
# # Тараз

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования Тараз",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%A2%D0%B0%D1%80%D0%B0%D0%B7

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Taraz=[]

for i in data2:
    Taraz.append(i['name'])

# %%
Taraz
# Out:
# ['Школа программирования ELEMENT']

# %%
TarazGeo=[]

for i in data2:
    TarazGeo.append(i['geometry']['location'])

# %%
TarazGeo
# Out:
# [{'lat': 42.8980067, 'lng': 71.37335519999999}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(42.8980067, 71.37335519999999,13)

# Add a marker
gmap.marker(42.8980067, 71.37335519999999, 'cornflowerblue')


gmap.marker(42.902425963701226, 71.37415288539273, 'red') 


# Draw map into HTML file
gmap.draw("Taraz.html")

# %% [markdown]
# # Павлодар

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования в Павлодаре",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%B2+%D0%9F%D0%B0%D0%B2%D0%BB%D0%BE%D0%B4%D0%B0%D1%80%D0%B5

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Pavlodar=[]

for i in data2:
    Pavlodar.append(i['name'])

# %%
Pavlodar
# Out:
# ['Школа программирования ELEMENT',
#  'Element group',
#  'Element group',
#  'GURU, студия IT - разработки',
#  'Innovative University of Eurasia',
#  'Srednyaya Shkola 18']

# %%
Pavlodar = Pavlodar[:3]

# %%
Pavlodar
# Out:
# ['Школа программирования ELEMENT', 'Element group', 'Element group']

# %%
PavlodarGeo=[]

for i in data2:
    PavlodarGeo.append(i['geometry']['location'])

# %%
PavlodarGeo = PavlodarGeo[:3]

# %%
PavlodarGeo
# Out:
# [{'lat': 43.2377768, 'lng': 76.911591},
#  {'lat': 43.2519254, 'lng': 76.9475448},
#  {'lat': 43.2279483, 'lng': 76.942921}]

# %% [markdown]
# # Талдыкорган

# %%
base_endpoint_places = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
params = {
    "key": api_key,
    "query": "школа программирования в Талдыкоргане",
}
params_encoded=urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?key=AIzaSyBH21pqbCRPgKdkElnQvEeCpNimEhYUki8&query=%D1%88%D0%BA%D0%BE%D0%BB%D0%B0+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F+%D0%B2+%D0%A2%D0%B0%D0%BB%D0%B4%D1%8B%D0%BA%D0%BE%D1%80%D0%B3%D0%B0%D0%BD%D0%B5

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %%
r2=r.text
data = json.loads(r2)
data2 = data['results']
Taldykorgan=[]

for i in data2:
    Taldykorgan.append(i['name'])

# %%
Taldykorgan
# Out:
# ['My Genius Taldykorgan',
#  'Компания "SkyTec"',
#  'Shkola Bastau',
#  'Future-IT школа робототехники',
#  'Курсы Английского Языка "LIGHT"',
#  'Гуманитарно-технический колледж «Білім»',
#  "Dvorets Shkol'nikov",
#  'Polytechnical college',
#  "Zhetysuskiy Sotsial'no-Gumanitarnyy Kolledzh",
#  'Nazarbayev Intellectual School']

# %%
Taldykorgan = Taldykorgan[:4]

# %%
Taldykorgan
# Out:
# ['My Genius Taldykorgan',
#  'Компания "SkyTec"',
#  'Shkola Bastau',
#  'Future-IT школа робототехники']

# %%
TaldykorganGeo=[]

for i in data2:
    TaldykorganGeo.append(i['geometry']['location'])

# %%
TaldykorganGeo = TaldykorganGeo[:4]

# %%
TaldykorganGeo
# Out:
# [{'lat': 45.01673359999999, 'lng': 78.377392},
#  {'lat': 45.016734, 'lng': 78.354621},
#  {'lat': 45.0162176, 'lng': 78.37788139999999},
#  {'lat': 45.00363369999999, 'lng': 78.3475797}]

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(45.01673359999999, 78.377392,13)

# Add a marker
gmap.marker(45.01673359999999, 78.377392, 'cornflowerblue')
gmap.marker(45.016734, 78.354621, 'cornflowerblue')
gmap.marker(45.0162176, 78.37788139999999, 'cornflowerblue')
gmap.marker(45.00363369999999, 78.3475797, 'cornflowerblue')


gmap.marker(45.00952107835951, 78.34907051708932, 'red') 
gmap.marker(45.018379873848744, 78.37473389226277, 'red') 

# Draw map into HTML file
gmap.draw("Taldykorgan.html")

# %% [markdown]
# # Казахстан

# %%
# Initialize the map at a given point
gmap = gmplot.GoogleMapPlotter(48.28801773530177, 67.58335989092271, 5.5)

# Add a marker
#Шымкент
gmap.marker(42.3439488, 69.6112757, 'cornflowerblue')
gmap.marker(42.3240687, 69.6067, 'cornflowerblue')
gmap.marker(42.3208953, 69.58055159999999, 'cornflowerblue')
gmap.marker(42.329284, 69.5970023, 'cornflowerblue')
gmap.marker(42.3213791, 69.5791572, 'cornflowerblue')

gmap.marker(42.3052730883907, 69.59688166090777, 'red')
gmap.marker(42.33984118738718, 69.60538241029927, 'red') 
gmap.marker(42.335526924779515, 69.64992853643648, 'red')


#Алматы
gmap.marker(43.2376794, 76.89740619999999, 'cornflowerblue')
gmap.marker(43.2380699, 76.9137973, 'cornflowerblue')
gmap.marker(43.2351, 76.9099014, 'cornflowerblue')
gmap.marker(43.2631325, 76.9276804, 'cornflowerblue')
gmap.marker(43.3270746, 76.9247955, 'cornflowerblue')
gmap.marker(43.2159755, 76.8701902, 'cornflowerblue')
gmap.marker(43.2521271, 76.89077929999999, 'cornflowerblue')
gmap.marker(43.2579834, 76.9110298, 'cornflowerblue')
gmap.marker(43.2509446, 76.9601978, 'cornflowerblue')
gmap.marker(43.2375723, 76.91292779999999, 'cornflowerblue')
gmap.marker(43.2380699, 76.9137973, 'cornflowerblue')
gmap.marker(43.2377768, 76.911591, 'cornflowerblue')
gmap.marker(43.2508112, 76.946806, 'cornflowerblue')
gmap.marker(43.2372245, 76.9331849, 'cornflowerblue')
gmap.marker(43.263117, 76.9276928, 'cornflowerblue')
gmap.marker(43.239846, 76.90185199999999, 'cornflowerblue')
gmap.marker(43.2461482, 76.9260887, 'cornflowerblue')
gmap.marker(43.2391981, 76.90500519999999, 'cornflowerblue')
gmap.marker(43.2301205, 76.89517130000002, 'cornflowerblue')
gmap.marker(43.2374166, 76.91521259999999, 'cornflowerblue')

gmap.marker(43.23662525403574, 76.92974368444, 'red') 
gmap.marker(43.255602755313745, 76.94312650419225, 'red') 
#gmap.marker(43.242166390579925, 76.95289778972162, 'red') 
gmap.marker(43.234678043219674, 76.93112482676837, 'red') 
gmap.marker(43.25287050610048, 76.9263269825901, 'red') 
gmap.marker(43.23530270849879, 76.90977698443994, 'red') 


#Нур-Султан
gmap.marker(51.1539059, 71.4989914, 'cornflowerblue')
gmap.marker(51.14691639999999, 71.4753933, 'cornflowerblue')
gmap.marker(51.1852333, 71.40690599999999, 'cornflowerblue')
gmap.marker(51.2352858, 71.4143205, 'cornflowerblue')
gmap.marker(51.1231148, 71.434456, 'cornflowerblue')
gmap.marker(51.1599248, 71.406046, 'cornflowerblue')
gmap.marker(51.1466678, 71.47745309999999, 'cornflowerblue')
gmap.marker(51.16467, 71.441425, 'cornflowerblue')
gmap.marker(51.1609949, 71.4355248, 'cornflowerblue')
gmap.marker(51.1436591, 71.4158732, 'cornflowerblue')
gmap.marker(51.0978825, 71.4226479, 'cornflowerblue')
gmap.marker(51.1593571, 71.4376502, 'cornflowerblue')
gmap.marker(51.1599248, 71.406046, 'cornflowerblue')
gmap.marker(51.1546386, 71.4512331, 'cornflowerblue')


gmap.marker(51.16964442152685, 71.40765194367495, 'red') 
gmap.marker(51.18535638621766, 71.4330578267898, 'red') 


#Актобе
gmap.marker(50.29429950000001, 57.1654041, 'cornflowerblue')
gmap.marker(50.2884052, 57.1659747, 'cornflowerblue')
gmap.marker(50.2963984, 57.1561017, 'cornflowerblue')

gmap.marker(50.28240070146561, 57.16130580229323, 'red') 
gmap.marker(50.28980435752049, 57.15298022573194, 'red') 

#Талдыкорган
gmap.marker(45.01673359999999, 78.377392, 'cornflowerblue')
gmap.marker(45.016734, 78.354621, 'cornflowerblue')
gmap.marker(45.0162176, 78.37788139999999, 'cornflowerblue')
gmap.marker(45.00363369999999, 78.3475797, 'cornflowerblue')


gmap.marker(45.00952107835951, 78.34907051708932, 'red') 
gmap.marker(45.018379873848744, 78.37473389226277, 'red') 


#Тараз
gmap.marker(42.8980067, 71.37335519999999, 'cornflowerblue')

gmap.marker(42.902425963701226, 71.37415288539273, 'red') 


#Караганда
gmap.marker(49.797829, 73.09049999999999, 'cornflowerblue')
gmap.marker(49.8164831, 73.1018766, 'cornflowerblue')
gmap.marker(49.7972366, 73.0954616, 'cornflowerblue')
gmap.marker(49.7848605, 73.116314, 'cornflowerblue')

gmap.marker(49.81888402480654, 73.10444275787144, 'red') 



# Draw map into HTML file
gmap.draw("Kazakhstan.html")

# %% [markdown]
# # Заносим данные в датафрейм

# %%
import pandas as pd

# %%
columns = ['Город','Школа']

# %%
df = pd.DataFrame(columns=columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Город, Школа]
# Index: []

# %%
Almaty
# Out:
# ['BITLAB Academy | Школа Программирования',
#  'Decode | Курсы программирования',
#  'Школа программирования в Алматы - IT School',
#  'Школа программирования KnewIT',
#  'Школа программирования Codeway',
#  'Школа программирования для детей Love to Code',
#  'Shkola Programmirovaniya Dlya Detey Yuniorkod',
#  'Школа программирования',
#  'Школа программирования для детей Love to Code',
#  'Курс Программирования с нуля - CodeGuru',
#  'Курсы программирования Keynote',
#  'Школа программирования ELEMENT',
#  'TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирования | Обучение программированию',
#  'Школа программирования NewLine',
#  'KnewIT',
#  'Школа программирования ITCreed',
#  'Algoritmika Almaty',
#  'Akademiya Shag Almaty',
#  'Pervaya Shkola Programirovaniya',
#  'Method Coding School']

# %%
df['Школа']=Almaty

# %%
df['Город'][0:20]='Алматы'

# %%
df
# Out:
#      Город                                              Школа
# 0   Алматы            BITLAB Academy | Школа Программирования
# 1   Алматы                    Decode | Курсы программирования
# 2   Алматы        Школа программирования в Алматы - IT School
# 3   Алматы                      Школа программирования KnewIT
# 4   Алматы                     Школа программирования Codeway
# 5   Алматы      Школа программирования для детей Love to Code
# 6   Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7   Алматы                             Школа программирования
# 8   Алматы      Школа программирования для детей Love to Code
# 9   Алматы            Курс Программирования с нуля - CodeGuru
# 10  Алматы                     Курсы программирования Keynote
# 11  Алматы                     Школа программирования ELEMENT
# 12  Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# 13  Алматы                     Школа программирования NewLine
# ...

# %%
df2 = pd.DataFrame(columns=columns)

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Город, Школа]
# Index: []

# %%
df2['Школа']=NurSultan

# %%
df2['Город'][0:15]='Нур-Султан'

# %%
df2
# Out:
#          Город                                              Школа
# 0   Нур-Султан      Shkola Programmirovaniya Dlya Detey "Softium"
# 1   Нур-Султан  ROBOSPACE - Школа робототехники и программиров...
# 2   Нур-Султан               Компьютерная Академия ШАГ. Казахстан
# 3   Нур-Султан                    Курсы программирования | Decode
# 4   Нур-Султан                    Академия ШАГ Астана Левый берег
# 5   Нур-Султан                   Mezhdunarodnaya Shkola Professiy
# 6   Нур-Султан                                          Kaysar777
# 7   Нур-Султан                     Центр программирования Runtime
# 8   Нур-Султан                                           Aytilekt
# 9   Нур-Султан  Центр Профессиональной Подготовки «Академия Ро...
# 10  Нур-Султан  Art School KZ Курсы вокала, Уроки фортепиано, ...
# 11  Нур-Султан  Центр Профессиональной Подготовки «Академия Ро...
# 12  Нур-Султан                    Tsentr Nlp I Kouchinga V Astane
# ...

# %%
df3=pd.DataFrame(columns=columns)

# %%
df3['Школа']=Aktobe
df3['Город']='Актобе'
df3
# Out:
#     Город                                   Школа
# 0  Актобе                          Pk Programmist
# 1  Актобе  Robotix - школа робототехники в Актобе
# 2  Актобе                Too "Uts Znaniye Aktobe"

# %%
df4=pd.DataFrame(columns=columns)

# %%
df4['Школа']=Shymkent
df4['Город']='Шымкент'
df4
# Out:
#      Город                                              Школа
# 0  Шымкент             Школа программирования ITSTART Шымкент
# 1  Шымкент      Школа программирования HITECH SCHOOL SHYMKENT
# 2  Шымкент                Kursy Programmirovaniya V Shymkente
# 3  Шымкент                    Школа программирования JUNIORIT
# 4  Шымкент  Mezhdunarodnaya Shkola Dizayna I Programmirova...

# %%
df5=pd.DataFrame(columns=columns)

# %%
df5['Школа']=Karaganda
df5['Город']='Караганда'
df5
# Out:
#        Город                                       Школа
# 0  Караганда                    Akademiya Shag Karagandy
# 1  Караганда              ikurs.kz образовательный центр
# 2  Караганда  Учебный центр Personal - Курсы в Караганде
# 3  Караганда                             State School 43

# %%
df6=pd.DataFrame(columns=columns)

# %%
df6['Школа']=Taraz
df6['Город']='Тараз'
df6
# Out:
#    Город                           Школа
# 0  Тараз  Школа программирования ELEMENT

# %%
df7=pd.DataFrame(columns=columns)

# %%
df7['Школа']=Taldykorgan
df7['Город']='Талдыкорган'
df7
# Out:
#          Город                          Школа
# 0  Талдыкорган          My Genius Taldykorgan
# 1  Талдыкорган              Компания "SkyTec"
# 2  Талдыкорган                  Shkola Bastau
# 3  Талдыкорган  Future-IT школа робототехники

# %%
new_df = pd.concat([df, df2, df3, df4, df5, df6, df7])

# %%
new_df
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
new_df = new_df.reset_index(drop=True)

# %%
new_df
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
new_df.to_csv("new_df.csv", index=False)

# %%
pd.read_csv('new_df.csv')
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('new_df.csv')  
df
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
df = df.drop([35,39])
df = df.reset_index(drop=True)
df
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
s = df['Школа'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#                                                 index  Школа
# 0   Центр Профессиональной Подготовки «Академия Ро...      2
# 1       Школа программирования для детей Love to Code      2
# 2                      Школа программирования ELEMENT      2
# 3   Art School KZ Курсы вокала, Уроки фортепиано, ...      1
# 4              Школа программирования ITSTART Шымкент      1
# 5                                      Pk Programmist      1
# 6                               My Genius Taldykorgan      1
# 7                       Школа программирования KnewIT      1
# 8   ROBOSPACE - Школа робототехники и программиров...      1
# 9                                  Algoritmika Almaty      1
# 10                     Школа программирования NewLine      1
# 11                             Школа программирования      1
# 12                              Akademiya Shag Almaty      1
# 13                    Decode | Курсы программирования      1
# ...

# %%
df.to_csv("df.csv", index=False)

# %%
len(df['Школа'])
# Out:
# 49

# %%
len(df['Школа'].unique())
# Out:
# 46

# %% [markdown]
# # Визуализация

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('df.csv')  
df
# Out:
#           Город                                              Школа
# 0        Алматы            BITLAB Academy | Школа Программирования
# 1        Алматы                    Decode | Курсы программирования
# 2        Алматы        Школа программирования в Алматы - IT School
# 3        Алматы                      Школа программирования KnewIT
# 4        Алматы                     Школа программирования Codeway
# 5        Алматы      Школа программирования для детей Love to Code
# 6        Алматы      Shkola Programmirovaniya Dlya Detey Yuniorkod
# 7        Алматы                             Школа программирования
# 8        Алматы      Школа программирования для детей Love to Code
# 9        Алматы            Курс Программирования с нуля - CodeGuru
# 10       Алматы                     Курсы программирования Keynote
# 11       Алматы                     Школа программирования ELEMENT
# 12       Алматы  TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирован...
# ...

# %%
df["Город"].value_counts().plot.bar()

plt.show()

# %%
df['Школа'].unique()
# Out:
# array(['BITLAB Academy | Школа Программирования',
#        'Decode | Курсы программирования',
#        'Школа программирования в Алматы - IT School',
#        'Школа программирования KnewIT', 'Школа программирования Codeway',
#        'Школа программирования для детей Love to Code',
#        'Shkola Programmirovaniya Dlya Detey Yuniorkod',
#        'Школа программирования',
#        'Курс Программирования с нуля - CodeGuru',
#        'Курсы программирования Keynote', 'Школа программирования ELEMENT',
#        'TEN ШКОЛА ПРОГРАММИСТОВ | Курсы программирования | Обучение программированию',
#        'Школа программирования NewLine', 'KnewIT',
#        'Школа программирования ITCreed', 'Algoritmika Almaty',
#        'Akademiya Shag Almaty', 'Pervaya Shkola Programirovaniya',
#        'Method Coding School',
#        'Shkola Programmirovaniya Dlya Detey "Softium"',
#        'ROBOSPACE - Школа робототехники и программирования',
#        'Компьютерная Академия ШАГ. Казахстан',
# ...

# %%
df2 = df.groupby(['Город'])[['Школа']].nunique()
df2
# Out:
#              Школа
# Город
# Актобе           2
# Алматы          19
# Караганда        4
# Нур-Султан      13
# Талдыкорган      4
# Тараз            1
# Шымкент          4

# %%
df2["Школа"].plot.bar()
plt.show()

# %%
# вузы Алматы
columns=['Город','Количество ВУЗово с IT-специальностями']
vuzy = pd.DataFrame(columns=columns)
vuzy
# Out:
# Empty DataFrame
# Columns: [Город, Количество ВУЗово с IT-специальностями]
# Index: []

# %%
# Ресурс - http://edu.resurs.kz/univer

# %%
#Алматы 5
vuzy = vuzy.append({'Город':'Алматы', 'Количество ВУЗово с IT-специальностями':5}, ignore_index=True)
vuzy
# Out:
#     Город Количество ВУЗово с IT-специальностями
# 0  Алматы                                      5

# %%
#Шымкент 3
vuzy = vuzy.append({'Город':'Шымкент', 'Количество ВУЗово с IT-специальностями':3}, ignore_index=True)

# %%
#Нур-Султан 2
vuzy = vuzy.append({'Город':'Нур-Султан', 'Количество ВУЗово с IT-специальностями':2}, ignore_index=True)

# %%
#Актобе 2
vuzy = vuzy.append({'Город':'Актобе', 'Количество ВУЗово с IT-специальностями':2}, ignore_index=True)

# %%
#Талдыкорган 2
vuzy = vuzy.append({'Город':'Талдыкорган', 'Количество ВУЗово с IT-специальностями':2}, ignore_index=True)

# %%
#Караганда 1
vuzy = vuzy.append({'Город':'Караганда', 'Количество ВУЗово с IT-специальностями':1}, ignore_index=True)

# %%
#Тараз 1
vuzy = vuzy.append({'Город':'Тараз', 'Количество ВУЗово с IT-специальностями':1}, ignore_index=True)

# %%
vuzy
# Out:
#          Город Количество ВУЗово с IT-специальностями
# 0       Алматы                                      5
# 1      Шымкент                                      3
# 2   Нур-Султан                                      2
# 3       Актобе                                      2
# 4  Талдыкорган                                      2
# 5    Караганда                                      1
# 6        Тараз                                      1

# %%
df2 = df.groupby(['Город'])[['Школа']].nunique()
df2
# Out:
#              Школа
# Город
# Актобе           2
# Алматы          19
# Караганда        4
# Нур-Султан      13
# Талдыкорган      4
# Тараз            1
# Шымкент          4

# %%
df_outer = pd.merge(vuzy, df2, on='Город', how='outer')

# %%
df_outer
# Out:
#          Город Количество ВУЗово с IT-специальностями  Школа
# 0       Алматы                                      5     19
# 1      Шымкент                                      3      4
# 2   Нур-Султан                                      2     13
# 3       Актобе                                      2      2
# 4  Талдыкорган                                      2      4
# 5    Караганда                                      1      4
# 6        Тараз                                      1      1

# %%
df_outer.columns = ['Город','Количество ВУЗов с IT-специальностями','Курсы программирования']

# %%
df_outer
# Out:
#          Город Количество ВУЗов с IT-специальностями  Курсы программирования
# 0       Алматы                                     5                      19
# 1      Шымкент                                     3                       4
# 2   Нур-Султан                                     2                      13
# 3       Актобе                                     2                       2
# 4  Талдыкорган                                     2                       4
# 5    Караганда                                     1                       4
# 6        Тараз                                     1                       1

# %%
df_outer["Курсы программирования"].plot.bar()
plt.show()

# %%
df_outer["Количество ВУЗов с IT-специальностями"].plot.bar()
plt.show()

# %%
df_outer.plot.bar(x='Город')

# %%
df_outer
# Out:
#          Город Количество ВУЗов с IT-специальностями  Курсы программирования
# 0       Алматы                                     5                      19
# 1      Шымкент                                     3                       4
# 2   Нур-Султан                                     2                      13
# 3       Актобе                                     2                       2
# 4  Талдыкорган                                     2                       4
# 5    Караганда                                     1                       4
# 6        Тараз                                     1                       1
